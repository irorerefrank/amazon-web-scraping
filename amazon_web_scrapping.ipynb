# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import time
import datetime
import csv
import smtplib
import pandas as pd

# %%
# connect to Amazon Website
from bs4 import BeautifulSoup
import requests

URL = "https://www.amazon.co.uk/Funny-Mug-Awesome-Analyst-Present/dp/B07HYYNTXW/ref=sr_1_5?crid=1114GJDQ5M128&dib=eyJ2IjoiMSJ9.sU7Sq0zvYreANe8JFsVT8vlXs23S9EvLyAfmipUSP1hyoBnlH72eo1lxdP2EJJ1gMraA0W0EyxSGg1WF73yJakLvaB9sLpAnB-WNoKWUpanf5QAPzE495GU7PiPh2mtb_bE_n3dYpYhIhlCevUEZo5CmqFI6Al6HIQPptCnuN3jVY_1TZvn-dD-lB-22htTiZVD8subatGbARGn0LGe71piRi3g4cIh0maJChZ7aoMiEpfwblKs2WLamCkkjrOppKPEADbFz4RIF8-PaLCI260X334Qv8JgQtgOweBkzExg.0cg5CfpW_Jq7D3YrPPWqJygFlfBV24t5fkGOwHTPbxM&dib_tag=se&keywords=data%2Banalyst%2Bcup&qid=1765450338&sprefix=data%2Banalyst%2Bcup%2Caps%2C80&sr=8-5"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "en-GB,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
}

response = requests.get(URL, headers=headers)
response.raise_for_status()

soup = BeautifulSoup(response.text, "html.parser")

# Extract the title
title_tag = soup.find(id="productTitle")
title = title_tag.get_text(strip=True) if title_tag else "Title not found"

# Extract the price
price = None

# Try common price selectors
selectors = [
    ("span", {"class": "a-offscreen"}),
    ("span", {"id": "priceblock_ourprice"}),
    ("span", {"id": "priceblock_dealprice"}),
    ("span", {"class": "a-price-whole"}),
]

for tag, attrs in selectors:
    found = soup.find(tag, attrs)
    if found and found.get_text(strip=True):
        price = found.get_text(strip=True)
        break

print("Product Title:", title)
print("Product Price:", price)
# Out:
# Product Title: Awesome Data Analyst - Printed Funny Mug - Great Gift/Present Idea, Ceramic, 11fl.oz.
# Product Price: £10.99

# %%
response = requests.get(URL, headers=headers)
response.raise_for_status()

soup = BeautifulSoup(response.text, "html.parser")

# Title
title_tag = soup.find(id="productTitle")
title = title_tag.get_text(strip=True) if title_tag else None

# Price
price_tag = soup.find("span", class_="a-offscreen")
price = price_tag.get_text(strip=True) if price_tag else None

print("Product Title:", title)
print("Product Price:", price)
# Out:
# Product Title: Awesome Data Analyst - Printed Funny Mug - Great Gift/Present Idea, Ceramic, 11fl.oz.
# Product Price: £10.99

# %%
title = title.strip()
price = price.replace("£", "").strip()

# %%
import datetime
today = datetime.date.today()

# %%
print(title)
# Out:
# Awesome Data Analyst - Printed Funny Mug - Great Gift/Present Idea, Ceramic, 11fl.oz.

# %%
print(price)
# Out:
# 10.99

# %%
print(today)
# Out:
# 2025-12-11

# %%
# To Create CSV and write headers and data into the file
import csv

header = ['Title', 'Price', 'Date']
data = [title, price, today]

with open(r"C:\Users\FRANK\Documents\AmazonWebScrappingDataset.csv", "w", newline="", encoding="UTF8") as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\FRANK
# ...

# %%
import pandas as pd
df = pd.read_csv("AmazonWebScrappingDataset.csv")
print(df)
# Out:
#                                                Title   Price        Date
# 0  Awesome Data Analyst - Printed Funny Mug - Gre...   10.99  2025-12-11
# 1  Awesome Data Analyst - Printed Funny Mug - Gre...   10.99  2025-12-11
# 2  Awesome Data Analyst - Printed Funny Mug - Gre...   10.99  2025-12-11
# 3  Awesome Data Analyst - Printed Funny Mug - Gre...  £10.99  2025-12-11
# 4  Awesome Data Analyst - Printed Funny Mug - Gre...  £10.99  2025-12-11
# 5  Awesome Data Analyst - Printed Funny Mug - Gre...  £10.99  2025-12-11

# %%
# Appending data to the csv
with open("AmazonWebScrappingDataset.csv", "a", newline="", encoding="UTF8") as f:
    writer = csv.writer(f)
    writer.writerow([title, price, today])

# %%
def check_price():
    URL = "https://www.amazon.co.uk/Funny-Mug-Awesome-Analyst-Present/dp/B07HYYNTXW/ref=sr_1_5?crid=1114GJDQ5M128&dib=eyJ2IjoiMSJ9.sU7Sq0zvYreANe8JFsVT8vlXs23S9EvLyAfmipUSP1hyoBnlH72eo1lxdP2EJJ1gMraA0W0EyxSGg1WF73yJakLvaB9sLpAnB-WNoKWUpanf5QAPzE495GU7PiPh2mtb_bE_n3dYpYhIhlCevUEZo5CmqFI6Al6HIQPptCnuN3jVY_1TZvn-dD-lB-22htTiZVD8subatGbARGn0LGe71piRi3g4cIh0maJChZ7aoMiEpfwblKs2WLamCkkjrOppKPEADbFz4RIF8-PaLCI260X334Qv8JgQtgOweBkzExg.0cg5CfpW_Jq7D3YrPPWqJygFlfBV24t5fkGOwHTPbxM&dib_tag=se&keywords=data%2Banalyst%2Bcup&qid=1765450338&sprefix=data%2Banalyst%2Bcup%2Caps%2C80&sr=8-5"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "en-GB,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
}

response = requests.get(URL, headers=headers)
response.raise_for_status()

soup = BeautifulSoup(response.text, "html.parser")

# Extract the title
title_tag = soup.find(id="productTitle")
title = title_tag.get_text(strip=True) if title_tag else "Title not found"

# Extract the price
price = None

# Try common price selectors
selectors = [
    ("span", {"class": "a-offscreen"}),
    ("span", {"id": "priceblock_ourprice"}),
    ("span", {"id": "priceblock_dealprice"}),
    ("span", {"class": "a-price-whole"}),
]

for tag, attrs in selectors:
    found = soup.find(tag, attrs)
    if found and found.get_text(strip=True):
        price = found.get_text(strip=True)
        break
    title = title.strip()
    price = price.replace("£", "").strip()

    import datetime
    today = datetime.date.today()

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open(r"C:\Users\FRANK\Documents\AmazonWebScrappingDataset.csv", "w", newline="", encoding="UTF8") as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 while(True):
# ----> 2     check_price()
#       3     time.sleep(5)
#
# NameError: name 'check_price' is not defined

# %%
with open("AmazonWebScrappingDataset.csv", "a", newline="", encoding="UTF8") as f:
    writer = csv.writer(f)
    writer.writerow([title, price, today])
print(df)
# Out:
#                                                Title   Price        Date
# 0  Awesome Data Analyst - Printed Funny Mug - Gre...   10.99  2025-12-11
# 1  Awesome Data Analyst - Printed Funny Mug - Gre...   10.99  2025-12-11
# 2  Awesome Data Analyst - Printed Funny Mug - Gre...   10.99  2025-12-11
# 3  Awesome Data Analyst - Printed Funny Mug - Gre...  £10.99  2025-12-11
# 4  Awesome Data Analyst - Printed Funny Mug - Gre...  £10.99  2025-12-11
# 5  Awesome Data Analyst - Printed Funny Mug - Gre...  £10.99  2025-12-11
